# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# 📍 DOĞRU DOSYA YOLU (Desktop'tan itibaren)
csv_path = "Desktop/data_analyst_job_analysis/data/data_analyst_jobs.csv"

# 📂 Çalışma dizinini yazdır
print("📂 Çalışma dizini:", os.getcwd())

# 📄 Dosya var mı kontrolü
print("📄 Dosya var mı?:", os.path.isfile(csv_path))

# ✅ CSV dosyasını oku
df = pd.read_csv(csv_path)

# 🔍 İlk 5 satırı yazdır
print("\n📌 İlk 5 Satır:")
print(df.head())

# 📐 Veri seti boyutu
print("\n📐 Veri boyutu:", df.shape)

# 🧱 Sütun bilgileri ve veri tipleri
print("\n🧱 Sütun bilgileri ve veri tipleri:")
print(df.info())

# ⚠️ Eksik değer kontrolü
print("\n⚠️ Eksik değer kontrolü:")
print(df.isnull().sum())

# ☁️ Açıklamalardan metin oluştur
text = " ".join(df["description"].astype(str))

# ☁️ WordCloud oluştur
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# 🎨 Görselleştir
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title(" Job Description WordCloud")
plt.show()

# 💾 Görseli kaydet
wordcloud.to_file("Desktop/data_analyst_job_analysis/visuals/job_description_wordcloud.png")
# Out:
# 📂 Çalışma dizini: /Users/yavuzcancolak
# 📄 Dosya var mı?: True
#
# 📌 İlk 5 Satır:
#                                                title  \
# 0                           HR Data Analytics Intern
# 1                                       Data Analyst
# 2                                       Data Analyst
# 3                                   Data Analyst III
# 4  Manager, Data Analytics - Reporting, SQL, Powe...
#
#                                                 link  \
# 0  https://www.remoterocketship.com/company/esvol...
# 1  https://www.remoterocketship.com/company/twili...
# 2  https://www.remoterocketship.com/company/datai...
# 3  https://www.remoterocketship.com/company/cente...
# 4  https://www.remoterocketship.com/company/cente...
#
#                                          description
# 0  • Build an HR Data & Performance Insights Play...
# 1  • The position is needed to provide actionable...
# 2  • Conduct in-depth analysis using the data war...
# ...
